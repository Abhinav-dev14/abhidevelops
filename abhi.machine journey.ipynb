# %%
import pandas as me
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model






abhi = me.read_excel(r"C:\Users\ASUS\Downloads\abh.csv.xlsx")# has to run this code first to not give error.
abhi
# Out:
#    area   price
# 0  2600   55000
# 1  3000   56500
# 2  3200    6100
# 3  3600   68000
# 4  4000  725000

# %%
# %matplotlib  inline
plt.scatter(abhi.area,abhi.price)

# %%
reg=linear_model.LinearRegression()
reg.fit(abhi[['area']],abhi.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])  #correct form
# Out:
# f:\c practice\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([190511.30136986])

# %%
reg.coef_
# Out:
# array([419.56506849])

# %%
reg.intercept_
# Out:
# np.float64(-1194053.4246575343)
